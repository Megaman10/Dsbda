# %% [markdown]
# Consider the Bangalore House Price Data. Perform following
# operations.
# a) Find and replace null values in the data using appropriate
# technique.
# b) Transform the ‘Size’ column to numerical values. For Example:
# 2 BHK to be converted as 2
# c) Transform the ‘total_sqft’ column to contain numerical values
# on same scale. If the range is given average value of the range to
# be taken.
# d) Calculate and add one more column as ‘Price_Per_Sqft’
# e) Remove the outliers from Price_Per_Sqft and BHK Size column
# if any.
# f) Apply the Linear Regression model to the data and display the
# training and testing performance measures as Mean Squared Error
# and Accuracy

# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv('/content/Banglore Housing Prices.csv')
dataframe.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %% [markdown]
# **a) Find and replace null values in the data using appropriate technique.**

# %%
dataframe.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %% [markdown]
# replace

# %%
dataframe['location'] = dataframe['location'].replace(np.nan, 'None')
dataframe['size'] = dataframe['size'].replace(np.nan, 'None')

# %% [markdown]
# fill with 0

# %%
dataframe['bath'].fillna(0, inplace=True)

# %%
dataframe.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %% [markdown]
# **b) Transform the ‘Size’ column to numerical values. For Example: 2 BHK to be converted as 2**

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
dataframe['size'] = label_encoder.fit_transform(dataframe['size'])
dataframe.head()
# Out:
#                    location  size total_sqft  bath   price
# 0  Electronic City Phase II    13       1056   2.0   39.07
# 1          Chikka Tirupathi    19       2600   5.0  120.00
# 2               Uttarahalli    16       1440   2.0   62.00
# 3        Lingadheeranahalli    16       1521   3.0   95.00
# 4                  Kothanur    13       1200   2.0   51.00

# %% [markdown]
# **c) Transform the ‘total_sqft’ column to contain numerical values on same scale. If the range is given average value of the range to be taken.**

# %%
dataframe.groupby('total_sqft').count()
# Out:
#              location  size  bath  price
# total_sqft
# 1                   1     1     1      1
# 1.25Acres           1     1     1      1
# 1.26Acres           1     1     1      1
# 1000              172   172   172    172
# 1000 - 1285         1     1     1      1
# ...               ...   ...   ...    ...
# 995                10    10    10     10
# 996                 4     4     4      4
# 997                 2     2     2      2
# 998                 1     1     1      1
# 999                 3     3     3      3
#
# [2117 rows x 4 columns]

# %% [markdown]
# **d) Calculate and add one more column as ‘Price_Per_Sqft’**

# %%
dataframe.dtypes
# Out:
# location       object
# size            int64
# total_sqft     object
# bath          float64
# price         float64
# dtype: object

# %%
# pd.to_numeric(dataframe['total_sqft'])
# ValueError: Unable to parse string "2100 - 2850" at position 30

# %%
def new_totalsqft(value):
  splited = value.split('-')
  if len(splited) == 2:
    return (float(splited[0]) + float(splited[1]))/2
  try:
    return float(value)
  except:
    return None

# %%
dataframe['new_totalsqft'] = dataframe['total_sqft'].apply(new_totalsqft)

# %%
dataframe.isnull().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# new_totalsqft    46
# dtype: int64

# %%
bool_sqft = dataframe['new_totalsqft'].isnull()
dataframe[bool_sqft]
# Out:
#                                            location  size       total_sqft  \
# 410                                         Kengeri     0   34.46Sq. Meter
# 648                                         Arekere    30        4125Perch
# 775                                    Basavanagara     0    1000Sq. Meter
# 872                               Singapura Village    13    1100Sq. Yards
# 6303    3.0   69.34            NaN
# 6333    2.0  200.00            NaN
# 6552    6.0  550.00            NaN
# 6592    4.0  211.00            NaN
# 6953    3.0  109.00            NaN
# 7001    6.0  290.00            NaN
# 7248    2.0   46.00            NaN
# 7334    1.0  125.00            NaN
# 7520    2.0   48.00            NaN
# 7607    3.0  217.00            NaN
# 7726    1.0  125.00            NaN
# 8273    2.0  150.00            NaN
# 9423    1.0   48.00            NaN
# 9519    3.0  232.00            NaN
# 9734    2.0   18.00            NaN
# 10488   2.0  200.00            NaN
# 10491   2.0   40.00            NaN
# 11320   1.0  170.00            NaN
# 11615   2.0   80.00            NaN
# 12186   2.0   51.00            NaN
# 12252   5.0   75.00            NaN
# 12560   3.0  110.00            NaN
# 12652   2.0  150.00            NaN

# %%
dataframe = dataframe.dropna()
dataframe.isnull().sum()
# Out:
# location         0
# size             0
# total_sqft       0
# bath             0
# price            0
# new_totalsqft    0
# dtype: int64

# %%
# price per square feet = price / total_sqft
dataframe['price_per_sqft'] = (dataframe['price'] * 100000) / dataframe['new_totalsqft']
dataframe
# Out:
#                        location  size total_sqft  bath   price  new_totalsqft  \
# 0      Electronic City Phase II    13       1056   2.0   39.07         1056.0
# 1              Chikka Tirupathi    19       2600   5.0  120.00         2600.0
# 2                   Uttarahalli    16       1440   2.0   62.00         1440.0
# 3            Lingadheeranahalli    16       1521   3.0   95.00         1521.0
# 4                      Kothanur    13       1200   2.0   51.00         1200.0
# ...                         ...   ...        ...   ...     ...            ...
# 13315                Whitefield    22       3453   4.0  231.00         3453.0
# 13316             Richards Town    18       3600   5.0  400.00         3600.0
# 13317     Raja Rajeshwari Nagar    13       1141   2.0   60.00         1141.0
# 13318           Padmanabhanagar    18       4689   4.0  488.00         4689.0
# 13319              Doddathoguru     0        550   1.0   17.00          550.0
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
# ...               ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
#
# [13274 rows x 7 columns]

# %% [markdown]
#  **e) Remove the outliers from Price_Per_Sqft and BHK Size column if any.**

# %%
dataframe.describe()
# Out:
#                size          bath         price  new_totalsqft  price_per_sqft
# count  13274.000000  13274.000000  13274.000000   13274.000000    1.327400e+04
# mean      14.814675      2.676360    112.453654    1559.626694    7.907501e+03
# std        4.474545      1.349933    149.070368    1238.405258    1.064296e+05
# min        0.000000      0.000000      8.000000       1.000000    2.678298e+02
# 25%       13.000000      2.000000     50.000000    1100.000000    4.266865e+03
# 50%       16.000000      2.000000     72.000000    1276.000000    5.434306e+03
# 75%       16.000000      3.000000    120.000000    1680.000000    7.311746e+03
# max       31.000000     40.000000   3600.000000   52272.000000    1.200000e+07

# %%
dataframe.shape
# Out:
# (13274, 7)

# %%
Q1 = dataframe['price_per_sqft'].quantile(.25)
Q3 = dataframe['price_per_sqft'].quantile(.75)

IQR = Q3 - Q1

upper = Q3 + (IQR*1.5)
lower = Q1 - (IQR*1.5)

dataframe[(dataframe['price_per_sqft'] > upper) | (dataframe['price_per_sqft'] < lower)].shape
# Out:
# (1268, 7)

# %% [markdown]
# There are 1268 outliers in the data

# %% [markdown]
# **Removing Outliers**

# %%
dataframe = dataframe[(dataframe['price_per_sqft'] < upper) & (dataframe['price_per_sqft'] > lower)]
dataframe
# Out:
#                        location  size total_sqft  bath   price  new_totalsqft  \
# 0      Electronic City Phase II    13       1056   2.0   39.07         1056.0
# 1              Chikka Tirupathi    19       2600   5.0  120.00         2600.0
# 2                   Uttarahalli    16       1440   2.0   62.00         1440.0
# 3            Lingadheeranahalli    16       1521   3.0   95.00         1521.0
# 4                      Kothanur    13       1200   2.0   51.00         1200.0
# ...                         ...   ...        ...   ...     ...            ...
# 13315                Whitefield    22       3453   4.0  231.00         3453.0
# 13316             Richards Town    18       3600   5.0  400.00         3600.0
# 13317     Raja Rajeshwari Nagar    13       1141   2.0   60.00         1141.0
# 13318           Padmanabhanagar    18       4689   4.0  488.00         4689.0
# 13319              Doddathoguru     0        550   1.0   17.00          550.0
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
# ...               ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
#
# [12006 rows x 7 columns]

# %% [markdown]
# REmvoing outliers from BHK Size

# %%
Q1 = dataframe['size'].quantile(.25)
Q3 = dataframe['size'].quantile(.75)

IQR = Q3 - Q1
lower = Q1 - (IQR * 1.5)
upper = Q3 + (IQR * 1.5)

# scanning for outliers
dataframe[(dataframe['size'] < lower) | (dataframe['size'] > upper)].shape
# Out:
# (1068, 7)

# %%
dataframe = dataframe[(dataframe['size'] > lower) & (dataframe['size'] < upper)]
dataframe
# Out:
#                        location  size total_sqft  bath   price  new_totalsqft  \
# 0      Electronic City Phase II    13       1056   2.0   39.07         1056.0
# 1              Chikka Tirupathi    19       2600   5.0  120.00         2600.0
# 2                   Uttarahalli    16       1440   2.0   62.00         1440.0
# 3            Lingadheeranahalli    16       1521   3.0   95.00         1521.0
# 4                      Kothanur    13       1200   2.0   51.00         1200.0
# ...                         ...   ...        ...   ...     ...            ...
# 13313               Uttarahalli    16       1345   2.0   57.00         1345.0
# 13314         Green Glen Layout    16       1715   3.0  112.00         1715.0
# 13316             Richards Town    18       3600   5.0  400.00         3600.0
# 13317     Raja Rajeshwari Nagar    13       1141   2.0   60.00         1141.0
# 13318           Padmanabhanagar    18       4689   4.0  488.00         4689.0
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
# ...               ...
# 13313     4237.918216
# 13314     6530.612245
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
#
# [10938 rows x 7 columns]

# %% [markdown]
# **f) Apply the Linear Regression model to the data and display the training and testing performance measures as Mean Squared Error and Accuracy**

# %%
import matplotlib.pyplot as plt 
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

df_linear = dataframe[['price', 'new_totalsqft']]
X = df_linear.drop('price', axis='columns')
Y = df_linear['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 10)

# %%
linear_regression = linear_model.LinearRegression()
linear_regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([0.04048073])

# %%
linear_regression.intercept_
# Out:
# 26.51142876049711

# %%
linear_regression.score(X_test, Y_test)
# Out:
# 0.5205021354117046

# %%
y_pred = linear_regression.predict(X_test)
print(mean_squared_error(Y_test, y_pred))
# Out:
# 1831.0732985828263

# %%
y_pred = linear_regression.predict(X_train)
print(mean_squared_error(Y_train, y_pred))
# Out:
# 2854.1099977133763
